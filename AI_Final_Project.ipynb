# %% [markdown]
# <a href="https://colab.research.google.com/github/HarisMashood/AI_Final_Project/blob/main/AI_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/AI_Final_Project.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/InferenceMode.h
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/input_buffer.h
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/input_metadata.h
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/jit_decomp_interface.h
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/profiler.h
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/profiler_kineto.h
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/profiler_legacy.h
#   inflating: /content/AI_Final_Project/.venv/Lib/site-packages/torch/include/torch/csrc/autograd/profiler_python.h
# ...

# %%
# %cd /content/AI_Final_Project
# Out:
# /content/AI_Final_Project

# %%
# !pip install torch torchvision opencv-python scikit-learn

# %%
# !python train.py
# Out:
# Starting epoch 1/50
# Epoch [1/50] completed, Training Loss: 0.2941
# Epoch [1/50], Validation Loss: 0.2951
# Model saved at epoch 1 with validation loss: 0.2951
# Starting epoch 2/50
# Epoch [2/50] completed, Training Loss: 0.1363
# Epoch [2/50], Validation Loss: 0.1087
# Model saved at epoch 2 with validation loss: 0.1087
# Starting epoch 3/50
# Epoch [3/50] completed, Training Loss: 0.0892
# Epoch [3/50], Validation Loss: 0.0626
# Model saved at epoch 3 with validation loss: 0.0626
# Starting epoch 4/50
# Epoch [4/50] completed, Training Loss: 0.0700
# Epoch [4/50], Validation Loss: 0.1902
# Starting epoch 5/50
# Epoch [5/50] completed, Training Loss: 0.0613
# Epoch [5/50], Validation Loss: 0.0625
# Model saved at epoch 5 with validation loss: 0.0625
# Starting epoch 6/50
# Epoch [6/50] completed, Training Loss: 0.0580
# Epoch [6/50], Validation Loss: 0.4393
# Starting epoch 7/50
# Epoch [7/50] completed, Training Loss: 0.0486
# Epoch [7/50], Validation Loss: 0.0525
# ...

# %%
# %run /content/AI_Final_Project/src/evaluate.py
# Out:
# /content/AI_Final_Project/src/evaluate.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import matplotlib.pyplot as plt

# Training and validation loss values from your updated output
train_loss_list = [
    0.2941, 0.1363, 0.0892, 0.0700, 0.0613, 0.0580, 0.0486, 0.0467, 0.0434, 0.0391,
    0.0390, 0.0357, 0.0311, 0.0317, 0.0320, 0.0310, 0.0277, 0.0265, 0.0258, 0.0244,
    0.0249, 0.0290, 0.0221, 0.0205, 0.0203, 0.0186, 0.0179, 0.0173, 0.0153, 0.0172,
    0.0166, 0.0143, 0.0135, 0.0139, 0.0164, 0.0129, 0.0112, 0.0127, 0.0112, 0.0112,
    0.0098, 0.0096, 0.0093, 0.0087, 0.0116, 0.0107, 0.0087, 0.0091, 0.0088, 0.0098
]
val_loss_list = [
    0.2951, 0.1087, 0.0626, 0.1902, 0.0625, 0.4393, 0.0525, 0.0593, 0.0339, 0.0366,
    0.0347, 0.0294, 0.0288, 0.0809, 0.1380, 0.0452, 0.0294, 0.0287, 0.0262, 0.0247,
    0.0257, 0.0226, 0.0230, 0.0156, 0.0437, 0.0142, 0.0504, 0.0150, 0.0211, 0.0460,
    0.0235, 0.0144, 0.0328, 0.0154, 0.0159, 0.0123, 0.0120, 0.0122, 0.0128, 0.0116,
    0.0116, 0.0118, 0.0135, 0.0111, 0.0109, 0.0165, 0.0089, 0.0121, 0.0100, 0.0103
]

# Plotting
epochs = range(1, len(train_loss_list) + 1)
plt.plot(epochs, train_loss_list, label='Training Loss')
plt.plot(epochs, val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Progression During Training')
plt.legend()
plt.savefig('../reports/loss_progression.png')  # Save the plot as a file
plt.show()

# %%
# %run /content/AI_Final_Project/src/inference.py
# Out:
# /content/AI_Final_Project/src/inference.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# %run /content/AI_Final_Project/src/inference.py
# Out:
# /content/AI_Final_Project/src/inference.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !zip -r AI_Final_Project.zip /content/AI_Final_Project
from google.colab import files
files.download('AI_Final_Project.zip')
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/masked/__pycache__/__init__.cpython-312.pyc (deflated 41%)
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/masked/__pycache__/_ops.cpython-312.pyc (deflated 65%)
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/masked/__pycache__/_docs.cpython-312.pyc (deflated 93%)
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/distributions/ (stored 0%)
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/distributions/laplace.py (deflated 67%)
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/distributions/categorical.py (deflated 69%)
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/distributions/dirichlet.py (deflated 70%)
#   adding: content/AI_Final_Project/.venv/Lib/site-packages/torch/distributions/mixture_same_family.py (deflated 75%)
# ...
